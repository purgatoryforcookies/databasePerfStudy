# %%
import requests

# The API endpoint
url = "http://84.249.42.208/info"

# A GET request to the API
response = requests.get(url)

t = response.text

ip = t.split()[4]

print(ip)
# Out:
# ---------------------------------------------------------------------------
# TimeoutError                              Traceback (most recent call last)
# File ~\AppData\Local\Programs\Python\Python311\Lib\http\client.py:1374, in HTTPConnection.getresponse(self)
#    1373 try:
# -> 1374     response.begin()
#    1375 except ConnectionError:
#
# File ~\AppData\Local\Programs\Python\Python311\Lib\http\client.py:318, in HTTPResponse.begin(self)
#     317 while True:
# --> 318     version, status, reason = self._read_status()
#     319     if status != CONTINUE:
#
# File ~\AppData\Local\Programs\Python\Python311\Lib\http\client.py:279, in HTTPResponse._read_status(self)
#     278 def _read_status(self):
# --> 279     line = str(self.fp.readline(_MAXLINE + 1), "iso-8859-1")
#     280     if len(line) > _MAXLINE:
#
# File ~\AppData\Local\Programs\Python\Python311\Lib\socket.py:706, in SocketIO.readinto(self, b)
#     705 try:
# --> 706     return self._sock.recv_into(b)
# ...

# %%
respIps = []

for i in range(1000):
    url = "http://84.249.42.208/info"

# A GET request to the API
    response = requests.get(url)

    t = response.text

    ip = t.split()[4]
    
    respIps.append(ip)
# Out:
# ---------------------------------------------------------------------------
# TimeoutError                              Traceback (most recent call last)
# File ~\AppData\Local\Programs\Python\Python311\Lib\http\client.py:1374, in HTTPConnection.getresponse(self)
#    1373 try:
# -> 1374     response.begin()
#    1375 except ConnectionError:
#
# File ~\AppData\Local\Programs\Python\Python311\Lib\http\client.py:318, in HTTPResponse.begin(self)
#     317 while True:
# --> 318     version, status, reason = self._read_status()
#     319     if status != CONTINUE:
#
# File ~\AppData\Local\Programs\Python\Python311\Lib\http\client.py:279, in HTTPResponse._read_status(self)
#     278 def _read_status(self):
# --> 279     line = str(self.fp.readline(_MAXLINE + 1), "iso-8859-1")
#     280     if len(line) > _MAXLINE:
#
# File ~\AppData\Local\Programs\Python\Python311\Lib\socket.py:706, in SocketIO.readinto(self, b)
#     705 try:
# --> 706     return self._sock.recv_into(b)
# ...

# %%
print(respIps)
# Out:
# ['10.42.0.10,', '10.42.0.11,', '10.42.0.11,', '10.42.0.11,', '10.42.0.9,', '10.42.0.10,', '10.42.0.10,', '10.42.0.10,', '10.42.0.11,', '10.42.0.11,', '10.42.0.9,', '10.42.0.9,', '10.42.0.11,', '10.42.0.9,', '10.42.0.9,', '10.42.0.9,', '10.42.0.10,', '10.42.0.10,', '10.42.0.11,', '10.42.0.9,', '10.42.0.10,', '10.42.0.10,', '10.42.0.11,', '10.42.0.11,', '10.42.0.11,', '10.42.0.10,', '10.42.0.11,', '10.42.0.11,', '10.42.0.9,', '10.42.0.11,', '10.42.0.11,', '10.42.0.11,', '10.42.0.10,', '10.42.0.11,', '10.42.0.9,', '10.42.0.10,', '10.42.0.9,', '10.42.0.10,', '10.42.0.9,', '10.42.0.9,', '10.42.0.10,', '10.42.0.10,', '10.42.0.9,', '10.42.0.11,', '10.42.0.10,', '10.42.0.9,', '10.42.0.9,', '10.42.0.10,', '10.42.0.10,', '10.42.0.9,', '10.42.0.9,', '10.42.0.9,', '10.42.0.10,', '10.42.0.9,', '10.42.0.9,', '10.42.0.9,', '10.42.0.10,', '10.42.0.9,', '10.42.0.10,', '10.42.0.9,', '10.42.0.11,', '10.42.0.10,', '10.42.0.9,', '10.42.0.10,', '10.42.0.11,', '10.42.0.9,', '10.42.0.10,', '10.42.0.10,', '1
# ...
